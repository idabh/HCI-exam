# %%
import random
import plotly.express as px
import plotly.graph_objects as go
import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from src.utils import *
import plotly.io as pio
pio.kaleido.scope.default_format = "png"

# %%
df = pd.read_csv('/Users/thearolskovsloth/Documents/MASTERS_I_COGSCI/second_sem/HCI/HCI-exam/Data/applicants-from-page-1.csv')
education_rank = {"high school":1, "bachelor":2, "masters":3, "phd":4, "postdoc":5}
df = df.iloc[:3,]
df
# Out:
#    Unnamed: 0              Name  Age                Sex  Python_score  \
# 0          11  Lionel Southward   55          nonbinary            87
# 1          15      Diana Cramer   20  prefer not to say            96
# 2          69       Roger Grant   52          nonbinary            70
#
#   Education_level             education      Faculty  workfields  \
# 0             phd  Information Sciences     sciences  accounting
# 1             phd     Software Engineer  engineering  accounting
# 2             phd            Journalist  engineering  accounting
#
#    Years_experience          image personality_profiles  \
# 0                26  download3.jpg   42_personality.png
# 1                35  download1.jpg   31_personality.png
# 2                40   download.jpg   28_personality.png
#
#                      strength  \
# 0  Efficient and a teamplayer
# 1             Great with tech
# 2             Great with tech
#
#                                                Text1  \
# 0  yay banana a banana words hello words is words...
# 1  this is of this selection selection hello a he...
# 2  is hello random random a of banana hello is ra...
#
#                                                Text2  factor1  factor2  \
# 0  is hello is random this selection this selecti...       38        6
# 1  yay cool is words is a of of yay banana select...       33        9
# 2  is this is selection selection hello hello ran...       35        7
#
#                                       skills  \
# 0       ['problem solving', 'excel', 'java']
# 1    ['java', 'communication', 'powerpoint']
# 2  ['powerpoint', 'juristics', 'management']
#
#                                    motivation_letter            ano_image
# 0  Through my veterinary science studies, I have ...  LionelSouthward.png
# 1  I grew up in a lower-income family with a sing...      DianaCramer.png
# 2  Studying at your school would help me develop ...       RogerGrant.png

# %%
def applicant_match(data):
    for individual in list(df['Name']):
        print(individual)
        d = data.loc[data['Name'] == individual]
        app_data = pd.DataFrame(dict(
        r=[ d.iloc[0,4]/10,
            education_rank[d.iloc[0,5]]*2,
            d.iloc[0,15]/5,
            d.iloc[0,16],
            d.iloc[0,9]/5],
        theta=['python skills','education_level','factor1',
            'factor2', 'experience']))
        individual = px.line_polar(app_data, r='r', theta='theta', line_close=True, template='ggplot2', range_r=[0,10],width=600, height=600)
        individual.update_traces(fill='toself')
        #if we want to change colors, look at Scatterpolar

        match_individual = go.Figure(data = individual.data,
            layout=go.Layout(
            polar={'radialaxis': {'visible': False}},width=600, height=600,
            showlegend=False))
        match_individual.update_polars(radialaxis_range=[0,10]) 
        match_individual.show()
        #match_individual.write_image((f"/Users/thearolskovsloth/Documents/MASTERS_I_COGSCI/second_sem/HCI/HCI-exam/Images/{individual}.png").replace(" ", ""))

# %%
applicant_match(df)
# Out:
# Lionel Southward
# /Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/express/_core.py:267: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/thearolskovsloth/Documents/MASTERS_I_COGSCI/second_sem/HCI/HCI-exam/thea_test.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/thearolskovsloth/Documents/MASTERS_I_COGSCI/second_sem/HCI/HCI-exam/thea_test.ipynb#ch0000003?line=0'>1</a> applicant_match(df)
#
# /Users/thearolskovsloth/Documents/MASTERS_I_COGSCI/second_sem/HCI/HCI-exam/thea_test.ipynb Cell 3' in applicant_match(data)
#      <a href='vscode-notebook-cell:/Users/thearolskovsloth/Documents/MASTERS_I_COGSCI/second_sem/HCI/HCI-exam/thea_test.ipynb#ch0000002?line=16'>17</a> match_individual = go.Figure(data = individual.data,
#      <a href='vscode-notebook-cell:/Users/thearolskovsloth/Documents/MASTERS_I_COGSCI/second_sem/HCI/HCI-exam/thea_test.ipynb#ch0000002?line=17'>18</a>     layout=go.Layout(
#      <a href='vscode-notebook-cell:/Users/thearolskovsloth/Documents/MASTERS_I_COGSCI/second_sem/HCI/HCI-exam/thea_test.ipynb#ch0000002?line=18'>19</a>     polar={'radialaxis': {'visible': False}},width=600, height=600,
#      <a href='vscode-notebook-cell:/Users/thearolskovsloth/Documents/MASTERS_I_COGSCI/second_sem/HCI/HCI-exam/thea_test.ipynb#ch0000002?line=19'>20</a>     showlegend=False))
#      <a href='vscode-notebook-cell:/Users/thearolskovsloth/Documents/MASTERS_I_COGSCI/second_sem/HCI/HCI-exam/thea_test.ipynb#ch0000002?line=20'>21</a> match_individual.update_polars(radialaxis_range=[0,10])
# ---> <a href='vscode-notebook-cell:/Users/thearolskovsloth/Documents/MASTERS_I_COGSCI/second_sem/HCI/HCI-exam/thea_test.ipynb#ch0000002?line=21'>22</a> match_individual.write_image((f"/Users/thearolskovsloth/Documents/MASTERS_I_COGSCI/second_sem/HCI/HCI-exam/Images/{individual}.png").replace(" ", ""))
#
# File ~/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/basedatatypes.py:3821, in BaseFigure.write_image(self, *args, **kwargs)
#    <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/basedatatypes.py?line=3760'>3761</a> """
#    <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/basedatatypes.py?line=3761'>3762</a> Convert a figure to a static image and write it to a file or writeable
#    <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/basedatatypes.py?line=3762'>3763</a> object
#    (...)
#    <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/basedatatypes.py?line=3816'>3817</a> None
#    <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/basedatatypes.py?line=3817'>3818</a> """
#    <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/basedatatypes.py?line=3818'>3819</a> import plotly.io as pio
# -> <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/basedatatypes.py?line=3820'>3821</a> return pio.write_image(self, *args, **kwargs)
#
# File ~/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/io/_kaleido.py:298, in write_image(fig, file, format, scale, width, height, validate, engine)
#     <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/io/_kaleido.py?line=287'>288</a>         raise ValueError(
#     <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/io/_kaleido.py?line=288'>289</a>             """
#     <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/io/_kaleido.py?line=289'>290</a> The 'file' argument '{file}' is not a string, pathlib.Path object, or file descriptor.
#    (...)
#     <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/io/_kaleido.py?line=292'>293</a>             )
#     <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/io/_kaleido.py?line=293'>294</a>         )
#     <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/io/_kaleido.py?line=294'>295</a>     else:
#     <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/io/_kaleido.py?line=295'>296</a>         # We previously succeeded in interpreting `file` as a pathlib object.
#     <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/io/_kaleido.py?line=296'>297</a>         # Now we can use `write_bytes()`.
# --> <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/site-packages/plotly/io/_kaleido.py?line=297'>298</a>         path.write_bytes(img_data)
#
# File ~/opt/anaconda3/envs/HCIenv/lib/python3.9/pathlib.py:1275, in Path.write_bytes(self, data)
#    <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/pathlib.py?line=1272'>1273</a> # type-check for the buffer interface before truncating the file
#    <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/pathlib.py?line=1273'>1274</a> view = memoryview(data)
# -> <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/pathlib.py?line=1274'>1275</a> with self.open(mode='wb') as f:
#    <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/pathlib.py?line=1275'>1276</a>     return f.write(view)
#
# File ~/opt/anaconda3/envs/HCIenv/lib/python3.9/pathlib.py:1252, in Path.open(self, mode, buffering, encoding, errors, newline)
#    <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/pathlib.py?line=1245'>1246</a> def open(self, mode='r', buffering=-1, encoding=None,
#    <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/pathlib.py?line=1246'>1247</a>          errors=None, newline=None):
#    <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/pathlib.py?line=1247'>1248</a>     """
#    <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/pathlib.py?line=1248'>1249</a>     Open the file pointed by this path and return a file object, as
#    <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/pathlib.py?line=1249'>1250</a>     the built-in open() function does.
#    <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/pathlib.py?line=1250'>1251</a>     """
# -> <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/pathlib.py?line=1251'>1252</a>     return io.open(self, mode, buffering, encoding, errors, newline,
#    <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/pathlib.py?line=1252'>1253</a>                    opener=self._opener)
#
# File ~/opt/anaconda3/envs/HCIenv/lib/python3.9/pathlib.py:1120, in Path._opener(self, name, flags, mode)
#    <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/pathlib.py?line=1117'>1118</a> def _opener(self, name, flags, mode=0o666):
#    <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/pathlib.py?line=1118'>1119</a>     # A stub for the opener argument to built-in open()
# -> <a href='file:///Users/thearolskovsloth/opt/anaconda3/envs/HCIenv/lib/python3.9/pathlib.py?line=1119'>1120</a>     return self._accessor.open(self, flags, mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: "/Users/thearolskovsloth/Documents/MASTERS_I_COGSCI/second_sem/HCI/HCI-exam/Images/Figure({\n'data':[{'fill':'toself',\n'hovertemplate':'r=%{r}<br>theta=%{theta}<extra></extra>',\n'legendgroup':'',\n'line':{'color':'#F8766D','dash':'solid'},\n'mode':'lines',\n'name':'',\n'r':array([8.7,8.,7.6,6.,5.2,8.7]),\n'showlegend':False,\n'subplot':'polar',\n'theta':[pythonskills,education_level,factor1,factor2,\nexperience,pythonskills],\n'type':'scatterpolar'}],\n'layout':{'height':600,\n'legend':{'tracegroupgap':0},\n'margin':{'t':60},\n'polar':{'angularaxis':{'direction':'clockwise','rotation':90},\n'domain':{'x':[0.0,1.0],'y':[0.0,1.0]},\n'radialaxis':{'range':[0,10]}},\n'template':'...',\n'width':600}\n}).png"
